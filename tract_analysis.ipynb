# %%
#organize the isd data by date-time
#get the numeric data from json columns

import pandas as pd
prop_census_isd = pd.read_csv("withredlining.csv")
#print all values in column that indicates census tract
print("Columns:")
print(prop_census_isd.columns.tolist())
prop_census_isd.grade.value_counts()
# prop_census_isd = prop_census_isd[['F2020_Census_Tracts_in_Boston_geoid20', 'tract2020_no_poly_csv_Housing_Vehicles_no_vehicles', 'tract2020_no_poly_csv_Housing_Vehicles_one_or_more_vehicles', 'tract2020_no_poly_csv_Housing_Vehicles_share_no_vehicles', 'tract2020_no_poly_csv_Housing_LivingArrangements_household_pop', 'tract2020_no_poly_csv_Housing_LivingArrangements_group_quarters', 'tract2020_no_poly_csv_Housing_LivingArrangements_avg_hh_size', 'tract2020_no_poly_csv_Housing_Tenure_owner', 'tract2020_no_poly_csv_Housing_Tenure_renter', 'tract2020_no_poly_csv_Housing_Units_vacant', 'tract2020_no_poly_csv_Housing_Units_occupied', 'tract2020_no_poly_csv_Housing_Units_total', 'tract2020_no_poly_csv_Housing_Units_vacancy_rate', 'tract2020_no_poly_csv_Housing_Units_units_per_acre', 'tract2020_no_poly_csv_Labor_Commute_total_workers_16_and_over', 'tract2020_no_poly_csv_Labor_Commute_car_truck_van_alone', 'tract2020_no_poly_csv_Labor_Commute_car_truck_van_carpool', 'tract2020_no_poly_csv_Labor_Commute_public_transportation', 'tract2020_no_poly_csv_Labor_Commute_walked', 'tract2020_no_poly_csv_Labor_Commute_taxi_moto_bike_other', 'tract2020_no_poly_csv_Labor_Commute_worked_from_home', 'tract2020_no_poly_csv_Labor_Commute_total_commuters', 'tract2020_no_poly_csv_Labor_Commute_share_public_tranportation', 'tract2020_no_poly_csv_Labor_Commute_share_walked', 'tract2020_no_poly_csv_Labor_Commute_share_car_truck_van', 'tract2020_no_poly_csv_Labor_Commute_share_worked_from_home', 'tract2020_no_poly_csv_Labor_LaborForce_in_labor_force_f', 'tract2020_no_poly_csv_Labor_LaborForce_in_labor_force_m', 'tract2020_no_poly_csv_Labor_LaborForce_not_in_labor_force_f', 'tract2020_no_poly_csv_Labor_LaborForce_not_in_labor_force_m', 'tract2020_no_poly_csv_Labor_LaborForce_female_participation_rate', 'tract2020_no_poly_csv_Labor_LaborForce_male_participation_rate', 'tract2020_no_poly_csv_Population_Race_white', 'tract2020_no_poly_csv_Population_Race_black_african_american', 'tract2020_no_poly_csv_Population_Race_other', 'tract2020_no_poly_csv_Population_Race_hispanic_latino', 'tract2020_no_poly_csv_Population_Race_american_indian_alaska_native', 'tract2020_no_poly_csv_Population_Race_asian_pacific_islander', 'tract2020_no_poly_csv_Population_Race_two_plus', 'tract2020_no_poly_csv_Population_Race_share_non_white', 'tract2020_no_poly_csv_Population_Race_share_black_african_american', 'tract2020_no_poly_csv_Population_Race_share_asian_pacific_islander', 'tract2020_no_poly_csv_Population_Race_share_hispanic_latino', 'tract2020_no_poly_csv_Population_Sex_male', 'tract2020_no_poly_csv_Population_Sex_female', 'tract2020_no_poly_csv_Population_Sex_total_pop', 'tract2020_no_poly_csv_Population_Sex_female_share', 'tract2020_no_poly_csv_Population_Density_pop_per_sq_mi', 'tract2020_no_poly_csv_Population_Nativity_native_born', 'tract2020_no_poly_csv_Population_Nativity_foreign_born', 'tract2020_no_poly_csv_Population_Nativity_share_foreign_born', 'tract2020_no_poly_csv_Population_Age_0_to_9', 'tract2020_no_poly_csv_Population_Age_10_to_19', 'tract2020_no_poly_csv_Population_Age_20_to_34', 'tract2020_no_poly_csv_Population_Age_35_to_54', 'tract2020_no_poly_csv_Population_Age_55_to_64', 'tract2020_no_poly_csv_Population_Age_65_plus', 'tract2020_no_poly_csv_Population_Age_share_0_to_9', 'tract2020_no_poly_csv_Population_Age_share_20_to_34', 'tract2020_no_poly_csv_Population_Age_share_55_plus', 'tract2020_no_poly_csv_Population_ChildrenByAge_under5', 'tract2020_no_poly_csv_Population_ChildrenByAge_5_to_17', 'tract2020_no_poly_csv_Population_ChildrenByAge_total_children', 'tract2020_no_poly_csv_Population_ChildrenByAge_share_children', 'tract2020_no_poly_csv_Income_Poverty_tot_pov_stat_det', 'tract2020_no_poly_csv_Income_Poverty_tot_below_pov', 'tract2020_no_poly_csv_Income_Poverty_tot_above_pov', 'tract2020_no_poly_csv_Income_Poverty_pov_rate', 'tract2020_no_poly_csv_Income_ChildrenByPoverty_chi_pov_stat_det', 'tract2020_no_poly_csv_Income_ChildrenByPoverty_chi_below_pov', 'tract2020_no_poly_csv_Income_ChildrenByPoverty_chi_above_pov', 'tract2020_no_poly_csv_Income_ChildrenByPoverty_chi_pov_rate', 'tract2020_no_poly_csv_Education_Attainment_LT_highschool', 'tract2020_no_poly_csv_Education_Attainment_highschool_equivalent', 'tract2020_no_poly_csv_Education_Attainment_some_college', 'tract2020_no_poly_csv_Education_Attainment_bachelors_more', 'tract2020_no_poly_csv_Education_Attainment_share_LT_highschool', 'tract2020_no_poly_csv_Education_Attainment_share_bachelors_more', 'sum_violation_count', 'totalpop']]
# tract_list = prop_census_isd['tract'].tolist()
print(prop_census_isd["totalpop"].describe())
df = prop_census_isd[prop_census_isd["totalpop"] > 1000]
# Out:
# Columns:
# ...

# %%
from scipy.stats import f_oneway
from pandas import CategoricalDtype
grade_type = CategoricalDtype(categories=['A', 'B', 'C', 'D', 'Commercial', 'Industrial'], ordered=True)
df['grade'] = df["grade"].astype(grade_type)
# df['grade'].cat.reorder_categories(ordered_grades, ordered=True)
target = "viol_pp"
df = df.dropna(subset=target)
groupA = df[df['grade'] == "A"][target]
groupB = df[df['grade'] == "B"][target]
groupC = df[df['grade'] == "C"][target]
groupD = df[df['grade'] == "D"][target]
groupInd = df[df['grade'] == "Industrial"][target]
groupCom = df[df['grade'] == "Commercial"][target]
# Out:
# C:\Users\shohi\AppData\Local\Temp\ipykernel_46228\1411896794.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['grade'] = df["grade"].astype(grade_type)

# %%
import scipy.stats as stats
F_statistic, p_value = stats.f_oneway(groupA, groupB, groupC, groupD, groupInd, groupCom)

# Get means
mean_groupA = groupA.mean()
mean_groupB = groupB.mean()
mean_groupC = groupC.mean()
mean_groupD = groupD.mean()
mean_groupInd = groupInd.mean()
mean_groupCom = groupCom.mean()

# Print the results
print("T-statistic:", F_statistic)
print("P-value:", p_value)
print("Mean groupA:", mean_groupA)
print("Mean groupB:", mean_groupB)
print("Mean groupC:", mean_groupC)
print("Mean groupD:", mean_groupD)
print("Mean groupInd:", mean_groupInd)
print("Mean groupCom:", mean_groupCom)

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as stats
# Out:
# T-statistic: 2.539124456979181
# P-value: 0.03006424284221367
# Mean groupA: 0.3684580423333334
# Mean groupB: 0.5364783298529412
# Mean groupC: 0.5358965510978261
# Mean groupD: 0.48327375530769234
# Mean groupInd: 0.17358619233333336
# Mean groupCom: 0.1728858515

# %%
# # Group our dataset with our 'Group' variable
grouped = df.groupby('grade')[target]
for name, group in grouped:
    print(name)
# Init a figure and axes
fig, ax = plt.subplots(figsize=(8, 6))

# Create the plot with different colors for each group
violins = ax.violinplot([group.values for name, group in grouped],
                     #labels=grouped.groups.keys()
                    ) 

# Define colors for each group
colors = ["#FDFFA5", "#FDA50A", "#DD513A", "#942668", "#420A68", "#000004"]

# Assign colors to each box in the boxplot
for violin, color in zip(violins['bodies'], colors):
    violin.set_facecolor(color)
    
# # Add the p value and the t
p_value_text = f'p-value: {p_value}'
ax.text(0.7, 1.07, p_value_text, weight='bold')
F_value_text = f'F-value: {F_statistic}'
ax.text(0.7, 1.0, F_value_text, weight='bold')

# # # Add the mean for each group
# # ax.text(1.25, mean_groupA, f'Mean of Group A: {mean_groupA}', fontsize=10)
# # ax.text(2.25, mean_groupB, f'Mean of Group B: {mean_groupB}', fontsize=10)
# # ax.text(2, mean_groupC, f'Mean of Group C: {mean_groupC}', fontsize=10)

# # Add a title and axis label
ax.set_title('One way Anova between 1938 HOLC Grades and Mean Violations Per Capita')
ax.set_xlabel("HOLC Grade")
ax.set_ylabel("Mean Violations Per Capita")

# # Add a legend
legend_labels = ['A - Best', 'B - Still Desirable', 'C - Definitely Declining', 'D - Hazardous', 'Commercial', 'Industrial']
legend_handles = [plt.Rectangle((0,0),1,1, color=color) for color in colors]
ax.legend(legend_handles, legend_labels)

# Display it
plt.show()
# Out:
# A
# B
# C
# D
# Commercial
# Industrial
# C:\Users\shohi\AppData\Local\Temp\ipykernel_46228\2962238025.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = df.groupby('grade')[target]

# %%
prop_census_isd.dropna(inplace=True)
prop_census_isd.columns.to_list()
# Out:
# ['OBJECTID',
#  'Join_Count',
#  'TARGET_FID',
#  'F2020_Census_Tracts_in_Boston_geoid20',
#  'F2020_Census_Tracts_in_Boston_countyfp20',
#  'F2020_Census_Tracts_in_Boston_namelsad20',
#  'F2020_Census_Tracts_in_Boston_statefp20',
#  'F2020_Census_Tracts_in_Boston_tractce20',
#  'F2020_Census_Tracts_in_Boston_intptlat20',
#  'F2020_Census_Tracts_in_Boston_name20',
#  'F2020_Census_Tracts_in_Boston_funcstat20',
#  'F2020_Census_Tracts_in_Boston_intptlon20',
#  'F2020_Census_Tracts_in_Boston_mtfcc20',
#  'F2020_Census_Tracts_in_Boston_aland20',
#  'F2020_Census_Tracts_in_Boston_awater20',
#  'F2020_Census_Tracts_in_Boston_objectid',
#  'F2020_Census_Tracts_in_Boston_inttractid',
#  'tract2020_no_poly_csv_GEOID20',
#  'tract2020_no_poly_csv_year',
#  'tract2020_no_poly_csv_Housing_Vehicles_no_vehicles',
#  'tract2020_no_poly_csv_Housing_Vehicles_one_or_more_vehicles',
#  'tract2020_no_poly_csv_Housing_Vehicles_share_no_vehicles',
# ...

# %%
withredlining = pd.read_csv("withredlining.csv")

# %%
from sklearn.feature_selection import RFE, RFECV
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import MinMaxScaler, RobustScaler, StandardScaler
from sklearn.model_selection import train_test_split

# %%
withredlining = pd.get_dummies(data=withredlining, columns=["grade"], prefix="holc_grade", drop_first=True, dtype="int64")
numeric_columns = withredlining.select_dtypes(include=['int64', 'float64']).columns.tolist()
tract_df = withredlining[numeric_columns].copy()
# print(tract_df.shape[0]-tract_df.dropna().shape[0])
# print(tract_df.dropna().shape[0])

# %%
tract_df.columns.tolist()
# Out:
# ['OBJECTID',
#  'Join_Count',
#  'TARGET_FID',
#  'F2020_Census_Tracts_in_Boston_geoid20',
#  'F2020_Census_Tracts_in_Boston_countyfp20',
#  'F2020_Census_Tracts_in_Boston_statefp20',
#  'F2020_Census_Tracts_in_Boston_tractce20',
#  'F2020_Census_Tracts_in_Boston_intptlat20',
#  'F2020_Census_Tracts_in_Boston_name20',
#  'F2020_Census_Tracts_in_Boston_intptlon20',
#  'F2020_Census_Tracts_in_Boston_aland20',
#  'F2020_Census_Tracts_in_Boston_awater20',
#  'F2020_Census_Tracts_in_Boston_objectid',
#  'F2020_Census_Tracts_in_Boston_inttractid',
#  'tract2020_no_poly_csv_GEOID20',
#  'tract2020_no_poly_csv_year',
#  'tract2020_no_poly_csv_Housing_Vehicles_no_vehicles',
#  'tract2020_no_poly_csv_Housing_Vehicles_one_or_more_vehicles',
#  'tract2020_no_poly_csv_Housing_Vehicles_share_no_vehicles',
#  'tract2020_no_poly_csv_Housing_LivingArrangements_household_pop',
#  'tract2020_no_poly_csv_Housing_LivingArrangements_group_quarters',
# ...

# %%
target = 'mean_violation_count'
tract_df = tract_df[['tract2020_no_poly_csv_Housing_Vehicles_no_vehicles',
 'tract2020_no_poly_csv_Housing_Vehicles_one_or_more_vehicles',
 'tract2020_no_poly_csv_Housing_Vehicles_share_no_vehicles',
 'tract2020_no_poly_csv_Housing_LivingArrangements_household_pop',
 'tract2020_no_poly_csv_Housing_LivingArrangements_group_quarters',
 'tract2020_no_poly_csv_Housing_LivingArrangements_avg_hh_size',
 'tract2020_no_poly_csv_Housing_Tenure_owner',
 'tract2020_no_poly_csv_Housing_Tenure_renter',
 'tract2020_no_poly_csv_Housing_Units_vacant',
 'tract2020_no_poly_csv_Housing_Units_occupied',
 'tract2020_no_poly_csv_Housing_Units_total',
 'tract2020_no_poly_csv_Housing_Units_vacancy_rate',
 'tract2020_no_poly_csv_Housing_Units_units_per_acre',
 'tract2020_no_poly_csv_Labor_Commute_total_workers_16_and_over',
 'tract2020_no_poly_csv_Labor_Commute_car_truck_van_alone',
 'tract2020_no_poly_csv_Labor_Commute_car_truck_van_carpool',
 'tract2020_no_poly_csv_Labor_Commute_public_transportation',
 'tract2020_no_poly_csv_Labor_Commute_walked',
 'tract2020_no_poly_csv_Labor_Commute_taxi_moto_bike_other',
 'tract2020_no_poly_csv_Labor_Commute_worked_from_home',
 'tract2020_no_poly_csv_Labor_Commute_total_commuters',
 'tract2020_no_poly_csv_Labor_Commute_share_public_tranportation',
 'tract2020_no_poly_csv_Labor_Commute_share_walked',
 'tract2020_no_poly_csv_Labor_Commute_share_car_truck_van',
 'tract2020_no_poly_csv_Labor_Commute_share_worked_from_home',
 'tract2020_no_poly_csv_Labor_LaborForce_in_labor_force_f',
 'tract2020_no_poly_csv_Labor_LaborForce_in_labor_force_m',
 'tract2020_no_poly_csv_Labor_LaborForce_not_in_labor_force_f',
 'tract2020_no_poly_csv_Labor_LaborForce_not_in_labor_force_m',
 'tract2020_no_poly_csv_Labor_LaborForce_female_participation_rate',
 'tract2020_no_poly_csv_Labor_LaborForce_male_participation_rate',
 'tract2020_no_poly_csv_Population_Race_white',
 'tract2020_no_poly_csv_Population_Race_black_african_american',
 'tract2020_no_poly_csv_Population_Race_other',
 'tract2020_no_poly_csv_Population_Race_hispanic_latino',
 'tract2020_no_poly_csv_Population_Race_american_indian_alaska_native',
 'tract2020_no_poly_csv_Population_Race_asian_pacific_islander',
 'tract2020_no_poly_csv_Population_Race_two_plus',
 'tract2020_no_poly_csv_Population_Race_share_non_white',
 'tract2020_no_poly_csv_Population_Race_share_black_african_american',
 'tract2020_no_poly_csv_Population_Race_share_asian_pacific_islander',
 'tract2020_no_poly_csv_Population_Race_share_hispanic_latino',
 'tract2020_no_poly_csv_Population_Sex_male',
 'tract2020_no_poly_csv_Population_Sex_female',
 'tract2020_no_poly_csv_Population_Sex_total_pop',
 'tract2020_no_poly_csv_Population_Sex_female_share',
 'tract2020_no_poly_csv_Population_Density_pop_per_sq_mi',
 'tract2020_no_poly_csv_Population_Nativity_native_born',
 'tract2020_no_poly_csv_Population_Nativity_foreign_born',
 'tract2020_no_poly_csv_Population_Nativity_share_foreign_born',
 'tract2020_no_poly_csv_Population_Age_0_to_9',
 'tract2020_no_poly_csv_Population_Age_10_to_19',
 'tract2020_no_poly_csv_Population_Age_20_to_34',
 'tract2020_no_poly_csv_Population_Age_35_to_54',
 'tract2020_no_poly_csv_Population_Age_55_to_64',
 'tract2020_no_poly_csv_Population_Age_65_plus',
 'tract2020_no_poly_csv_Population_Age_share_0_to_9',
 'tract2020_no_poly_csv_Population_Age_share_20_to_34',
 'tract2020_no_poly_csv_Population_Age_share_55_plus',
 'tract2020_no_poly_csv_Population_ChildrenByAge_under5',
 'tract2020_no_poly_csv_Population_ChildrenByAge_5_to_17',
 'tract2020_no_poly_csv_Population_ChildrenByAge_total_children',
 'tract2020_no_poly_csv_Population_ChildrenByAge_share_children',
 'tract2020_no_poly_csv_Income_Poverty_tot_pov_stat_det',
 'tract2020_no_poly_csv_Income_Poverty_tot_below_pov',
 'tract2020_no_poly_csv_Income_Poverty_tot_above_pov',
 'tract2020_no_poly_csv_Income_Poverty_pov_rate',
 'tract2020_no_poly_csv_Income_ChildrenByPoverty_chi_pov_stat_det',
 'tract2020_no_poly_csv_Income_ChildrenByPoverty_chi_below_pov',
 'tract2020_no_poly_csv_Income_ChildrenByPoverty_chi_above_pov',
 'tract2020_no_poly_csv_Income_ChildrenByPoverty_chi_pov_rate',
 'tract2020_no_poly_csv_Education_Attainment_LT_highschool',
 'tract2020_no_poly_csv_Education_Attainment_highschool_equivalent',
 'tract2020_no_poly_csv_Education_Attainment_some_college',
 'tract2020_no_poly_csv_Education_Attainment_bachelors_more',
 'tract2020_no_poly_csv_Education_Attainment_share_LT_highschool',
 'tract2020_no_poly_csv_Education_Attainment_share_bachelors_more', 'holc_grade_B',
 'holc_grade_C',
 'holc_grade_Commercial',
 'holc_grade_D',
 'holc_grade_Industrial', target]]

# %%
tract_df = tract_df.dropna()
X = tract_df.drop(columns=target)
print(X.info(verbose=True))
y = tract_df[[target]]
xscaler = StandardScaler()
xscaler.fit(X)
oldX = X
X = xscaler.transform(X)
Xtrain, Xtest, ytrain, ytest = train_test_split(X, y)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 186 entries, 0 to 203
# Data columns (total 82 columns):
#  #   Column                                                               Non-Null Count  Dtype
# ---  ------                                                               --------------  -----
#  0   tract2020_no_poly_csv_Housing_Vehicles_no_vehicles                   186 non-null    float64
#  1   tract2020_no_poly_csv_Housing_Vehicles_one_or_more_vehicles          186 non-null    float64
#  2   tract2020_no_poly_csv_Housing_Vehicles_share_no_vehicles             186 non-null    float64
#  3   tract2020_no_poly_csv_Housing_LivingArrangements_household_pop       186 non-null    float64
#  4   tract2020_no_poly_csv_Housing_LivingArrangements_group_quarters      186 non-null    float64
#  5   tract2020_no_poly_csv_Housing_LivingArrangements_avg_hh_size         186 non-null    float64
# ...

# %%
lr = LinearRegression()
lr.fit(Xtrain, ytrain)
# Out:
# LinearRegression()

# %%
lr.score(Xtest, ytest)
# Out:
# -0.15335043892214806

# %%
for i in range(1, 20):
    lr = LinearRegression()

    fixer = RFECV(lr, min_features_to_select=i)
    fixer.fit(Xtrain, ytrain)
    print(i, fixer.score(Xtest, ytest), fixer.get_feature_names_out())
# Out:
# 1 -0.029846940385062304 ['x67']
# 2 0.015388849878987254 ['x44' 'x63' 'x64' 'x65' 'x67' 'x68' 'x69']
# 3 0.015388849878987254 ['x44' 'x63' 'x64' 'x65' 'x67' 'x68' 'x69']
# 4 0.015388849878987254 ['x44' 'x63' 'x64' 'x65' 'x67' 'x68' 'x69']
# 5 0.015388849878987254 ['x44' 'x63' 'x64' 'x65' 'x67' 'x68' 'x69']
# 6 0.015388849878987254 ['x44' 'x63' 'x64' 'x65' 'x67' 'x68' 'x69']
# 7 0.015388849878987254 ['x44' 'x63' 'x64' 'x65' 'x67' 'x68' 'x69']
# 8 0.014009386719086692 ['x43' 'x44' 'x63' 'x64' 'x65' 'x67' 'x68' 'x69']
# 9 -0.12527815040070212 ['x0' 'x1' 'x2' 'x3' 'x4' 'x5' 'x6' 'x7' 'x8' 'x9' 'x10' 'x11' 'x13' 'x14'
#  'x15' 'x16' 'x17' 'x18' 'x19' 'x20' 'x22' 'x23' 'x25' 'x26' 'x27' 'x28'
#  'x31' 'x32' 'x33' 'x34' 'x35' 'x36' 'x37' 'x38' 'x39' 'x40' 'x41' 'x42'
#  'x43' 'x44' 'x47' 'x48' 'x49' 'x50' 'x51' 'x52' 'x53' 'x54' 'x55' 'x56'
#  'x59' 'x60' 'x61' 'x62' 'x63' 'x64' 'x65' 'x66' 'x67' 'x68' 'x69']
# ...

# %%
fixer = RFE(lr, n_features_to_select=6)

# %%
fixer.fit(Xtrain, ytrain)
# Out:
# RFE(estimator=LinearRegression(), n_features_to_select=6)

# %%
fixer.score(Xtest, ytest)
# Out:
# 0.015027051234510647

# %%
fixer.get_feature_names_out()
# Out:
# array(['x63', 'x64', 'x65', 'x67', 'x68', 'x69'], dtype=object)

# %%
minimod = prop_census_isd[['OBJECTID', 'tract2020_no_poly_csv_Population_Race_share_black_african_american', 'tract2020_no_poly_csv_Income_Poverty_tot_pov_stat_det',
       'tract2020_no_poly_csv_Income_Poverty_tot_below_pov',
       'tract2020_no_poly_csv_Income_Poverty_tot_above_pov',
       'tract2020_no_poly_csv_Income_ChildrenByPoverty_chi_pov_stat_det',
       'tract2020_no_poly_csv_Income_ChildrenByPoverty_chi_below_pov',
       'tract2020_no_poly_csv_Income_ChildrenByPoverty_chi_above_pov']]
X2 = prop_census_isd[['tract2020_no_poly_csv_Income_Poverty_tot_pov_stat_det',
       'tract2020_no_poly_csv_Income_Poverty_tot_below_pov',
       'tract2020_no_poly_csv_Income_Poverty_tot_above_pov',
       'tract2020_no_poly_csv_Income_ChildrenByPoverty_chi_pov_stat_det',
       'tract2020_no_poly_csv_Income_ChildrenByPoverty_chi_below_pov',
       'tract2020_no_poly_csv_Income_ChildrenByPoverty_chi_above_pov']]
X2train, X2test, y2train, y2test = train_test_split(X2, y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 13
#       1 minimod = prop_census_isd[['OBJECTID', 'tract2020_no_poly_csv_Population_Race_share_black_african_american', 'tract2020_no_poly_csv_Income_Poverty_tot_pov_stat_det',
#       2        'tract2020_no_poly_csv_Income_Poverty_tot_below_pov',
#       3        'tract2020_no_poly_csv_Income_Poverty_tot_above_pov',
#       4        'tract2020_no_poly_csv_Income_ChildrenByPoverty_chi_pov_stat_det',
#       5        'tract2020_no_poly_csv_Income_ChildrenByPoverty_chi_below_pov',
#       6        'tract2020_no_poly_csv_Income_ChildrenByPoverty_chi_above_pov']]
#       7 X2 = prop_census_isd[['tract2020_no_poly_csv_Income_Poverty_tot_pov_stat_det',
#       8        'tract2020_no_poly_csv_Income_Poverty_tot_below_pov',
#       9        'tract2020_no_poly_csv_Income_Poverty_tot_above_pov',
# ...

# %%
lr2 = LinearRegression()
lr2.fit(X2train, y2train)
# Out:
# LinearRegression()

# %%
lr2.score(X2test, y2test)
# Out:
# 0.30732726254727316

# %%
lr2.coef_
# Out:
# array([[ 7.11242228e+08, -7.11242227e+08, -7.11242227e+08,
#          1.80598074e+09, -1.80598074e+09, -1.80598074e+09]])

# %%
y2pred = lr2.predict(X2test)

# %%
import seaborn as sns


y2test["predicted_viols"] = y2pred

y2test.info(verbose=True)
sns.regplot(data = y2test, x="sum_violation_count", y="predicted_viols")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 47 entries, 41 to 68
# Data columns (total 2 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   sum_violation_count  47 non-null     int64
#  1   predicted_viols      47 non-null     float64
# dtypes: float64(1), int64(1)
# memory usage: 1.1 KB
# <Axes: xlabel='sum_violation_count', ylabel='predicted_viols'>

# %%
import sklearn
for depth in range(1, 20):
    treereg = sklearn.tree.DecisionTreeRegressor(max_depth=depth)
    treereg.fit(Xtrain, ytrain)
    print(depth, treereg.score(Xtest, ytest))
# Out:
# 1 0.10501469328574753
# 2 0.05944328085348871
# 3 -0.21585248513815447
# 4 -0.4857766009305349
# 5 -0.9970865015383263
# 6 -0.8012522565067381
# 7 -0.6372291461878195
# 8 -0.8267367543362414
# 9 -0.9370085777882435
# 10 -0.6217301452381709
# 11 -0.8275528234266367
# 12 -0.8181710703419012
# 13 -0.9409416538086606
# 14 -0.6577381256229271
# 15 -0.6248084157247977
# 16 -0.9366856630287419
# 17 -0.7307177784054733
# 18 -0.766305790830371
# 19 -0.7241413951730626

# %%
treereg = sklearn.tree.DecisionTreeRegressor(max_depth=3)
treereg.fit(Xtrain, ytrain)
sklearn.tree.plot_tree(treereg, feature_names= oldX.columns, filled=True, fontsize=5, rounded=True)
# Out:
# [Text(0.4230769230769231, 0.875, 'tract2020_no_poly_csv_Population_Race_white <= -0.849\nsquared_error = 0.23\nsamples = 139\nvalue = 1.266'),
#  Text(0.15384615384615385, 0.625, 'tract2020_no_poly_csv_Population_Density_pop_per_sq_mi <= -1.008\nsquared_error = 0.353\nsamples = 34\nvalue = 1.619'),
#  Text(0.28846153846153844, 0.75, 'True  '),
#  Text(0.07692307692307693, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 3.418'),
#  Text(0.23076923076923078, 0.375, 'tract2020_no_poly_csv_Population_Age_share_0_to_9 <= 1.213\nsquared_error = 0.262\nsamples = 33\nvalue = 1.565'),
#  Text(0.15384615384615385, 0.125, 'squared_error = 0.187\nsamples = 19\nvalue = 1.349'),
#  Text(0.3076923076923077, 0.125, 'squared_error = 0.217\nsamples = 14\nvalue = 1.856'),
#  Text(0.6923076923076923, 0.625, 'tract2020_no_poly_csv_Population_Age_share_55_plus <= 0.156\nsquared_error = 0.137\nsamples = 105\nvalue = 1.152'),
#  Text(0.5576923076923077, 0.75, '  False'),
# ...

# %%
withredlining = pd.read_csv("withredlining.csv")
target = "grade"
grade_type = CategoricalDtype(categories=['A', 'B', 'C', 'D', 'Commercial', 'Industrial'], ordered=True)
withredlining['grade'] = withredlining["grade"].astype(grade_type)
tract_df = withredlining[['tract2020_no_poly_csv_Housing_Vehicles_no_vehicles',
 'tract2020_no_poly_csv_Housing_Vehicles_one_or_more_vehicles',
 'tract2020_no_poly_csv_Housing_Vehicles_share_no_vehicles',
 'tract2020_no_poly_csv_Housing_LivingArrangements_household_pop',
 'tract2020_no_poly_csv_Housing_LivingArrangements_group_quarters',
 'tract2020_no_poly_csv_Housing_LivingArrangements_avg_hh_size',
 'tract2020_no_poly_csv_Housing_Tenure_owner',
 'tract2020_no_poly_csv_Housing_Tenure_renter',
 'tract2020_no_poly_csv_Housing_Units_vacant',
 'tract2020_no_poly_csv_Housing_Units_occupied',
 'tract2020_no_poly_csv_Housing_Units_total',
 'tract2020_no_poly_csv_Housing_Units_vacancy_rate',
 'tract2020_no_poly_csv_Housing_Units_units_per_acre',
 'tract2020_no_poly_csv_Labor_Commute_total_workers_16_and_over',
 'tract2020_no_poly_csv_Labor_Commute_car_truck_van_alone',
 'tract2020_no_poly_csv_Labor_Commute_car_truck_van_carpool',
 'tract2020_no_poly_csv_Labor_Commute_public_transportation',
 'tract2020_no_poly_csv_Labor_Commute_walked',
 'tract2020_no_poly_csv_Labor_Commute_taxi_moto_bike_other',
 'tract2020_no_poly_csv_Labor_Commute_worked_from_home',
 'tract2020_no_poly_csv_Labor_Commute_total_commuters',
 'tract2020_no_poly_csv_Labor_Commute_share_public_tranportation',
 'tract2020_no_poly_csv_Labor_Commute_share_walked',
 'tract2020_no_poly_csv_Labor_Commute_share_car_truck_van',
 'tract2020_no_poly_csv_Labor_Commute_share_worked_from_home',
 'tract2020_no_poly_csv_Labor_LaborForce_in_labor_force_f',
 'tract2020_no_poly_csv_Labor_LaborForce_in_labor_force_m',
 'tract2020_no_poly_csv_Labor_LaborForce_not_in_labor_force_f',
 'tract2020_no_poly_csv_Labor_LaborForce_not_in_labor_force_m',
 'tract2020_no_poly_csv_Labor_LaborForce_female_participation_rate',
 'tract2020_no_poly_csv_Labor_LaborForce_male_participation_rate',
 'tract2020_no_poly_csv_Population_Race_white',
 'tract2020_no_poly_csv_Population_Race_black_african_american',
 'tract2020_no_poly_csv_Population_Race_other',
 'tract2020_no_poly_csv_Population_Race_hispanic_latino',
 'tract2020_no_poly_csv_Population_Race_american_indian_alaska_native',
 'tract2020_no_poly_csv_Population_Race_asian_pacific_islander',
 'tract2020_no_poly_csv_Population_Race_two_plus',
 'tract2020_no_poly_csv_Population_Race_share_non_white',
 'tract2020_no_poly_csv_Population_Race_share_black_african_american',
 'tract2020_no_poly_csv_Population_Race_share_asian_pacific_islander',
 'tract2020_no_poly_csv_Population_Race_share_hispanic_latino',
 'tract2020_no_poly_csv_Population_Sex_male',
 'tract2020_no_poly_csv_Population_Sex_female',
 'tract2020_no_poly_csv_Population_Sex_total_pop',
 'tract2020_no_poly_csv_Population_Sex_female_share',
 'tract2020_no_poly_csv_Population_Density_pop_per_sq_mi',
 'tract2020_no_poly_csv_Population_Nativity_native_born',
 'tract2020_no_poly_csv_Population_Nativity_foreign_born',
 'tract2020_no_poly_csv_Population_Nativity_share_foreign_born',
 'tract2020_no_poly_csv_Population_Age_0_to_9',
 'tract2020_no_poly_csv_Population_Age_10_to_19',
 'tract2020_no_poly_csv_Population_Age_20_to_34',
 'tract2020_no_poly_csv_Population_Age_35_to_54',
 'tract2020_no_poly_csv_Population_Age_55_to_64',
 'tract2020_no_poly_csv_Population_Age_65_plus',
 'tract2020_no_poly_csv_Population_Age_share_0_to_9',
 'tract2020_no_poly_csv_Population_Age_share_20_to_34',
 'tract2020_no_poly_csv_Population_Age_share_55_plus',
 'tract2020_no_poly_csv_Population_ChildrenByAge_under5',
 'tract2020_no_poly_csv_Population_ChildrenByAge_5_to_17',
 'tract2020_no_poly_csv_Population_ChildrenByAge_total_children',
 'tract2020_no_poly_csv_Population_ChildrenByAge_share_children',
 'tract2020_no_poly_csv_Income_Poverty_tot_pov_stat_det',
 'tract2020_no_poly_csv_Income_Poverty_tot_below_pov',
 'tract2020_no_poly_csv_Income_Poverty_tot_above_pov',
 'tract2020_no_poly_csv_Income_Poverty_pov_rate',
 'tract2020_no_poly_csv_Income_ChildrenByPoverty_chi_pov_stat_det',
 'tract2020_no_poly_csv_Income_ChildrenByPoverty_chi_below_pov',
 'tract2020_no_poly_csv_Income_ChildrenByPoverty_chi_above_pov',
 'tract2020_no_poly_csv_Income_ChildrenByPoverty_chi_pov_rate',
 'tract2020_no_poly_csv_Education_Attainment_LT_highschool',
 'tract2020_no_poly_csv_Education_Attainment_highschool_equivalent',
 'tract2020_no_poly_csv_Education_Attainment_some_college',
 'tract2020_no_poly_csv_Education_Attainment_bachelors_more',
 'tract2020_no_poly_csv_Education_Attainment_share_LT_highschool',
 'tract2020_no_poly_csv_Education_Attainment_share_bachelors_more', 
 'sum_violation_count',
 'mean_violation_count',
 'max_violation_count', target]]

# %%
tract_df.dropna(inplace=True)
Xraw = tract_df.drop(columns=target)
y = tract_df[[target]]
xscaler = StandardScaler()
xscaler.fit(Xraw)
X = xscaler.transform(Xraw)
Xtrain, Xtest, ytrain, ytest = train_test_split(Xraw, y)
# Out:
# C:\Users\shohi\AppData\Local\Temp\ipykernel_46228\2672313509.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tract_df.dropna(inplace=True)

# %%
for i in range(1, 20):
    classtree = sklearn.tree.DecisionTreeClassifier(max_depth=i)
    classtree.fit(Xtrain, ytrain)
    print(i, classtree.score(Xtest, ytest))
# Out:
# 1 0.6170212765957447
# 2 0.6382978723404256
# 3 0.6595744680851063
# 4 0.574468085106383
# 5 0.5957446808510638
# 6 0.5531914893617021
# 7 0.574468085106383
# 8 0.574468085106383
# 9 0.5531914893617021
# 10 0.574468085106383
# 11 0.574468085106383
# 12 0.5957446808510638
# 13 0.574468085106383
# 14 0.5957446808510638
# 15 0.5957446808510638
# 16 0.5531914893617021
# 17 0.5106382978723404
# 18 0.5531914893617021
# 19 0.574468085106383

# %%
classtree = sklearn.tree.DecisionTreeClassifier(max_depth=3)
classtree.fit(Xtrain, ytrain)


import matplotlib.pyplot as plt

# Create a figure with large dimensions (e.g., 20x10 inches)
plt.figure(figsize=(20, 10))

ax = fig.add_subplot(1, 1, 1)
artists = sklearn.tree.plot_tree(classtree, feature_names= ['Housing_Vehicles_no_vehicles',
 'Housing_Vehicles_one_or_more_vehicles',
 'Housing_Vehicles_share_no_vehicles',
 'Housing_LivingArrangements_household_pop',
 'Housing_LivingArrangements_group_quarters',
 'Housing_LivingArrangements_avg_hh_size',
 'Housing_Tenure_owner',
 'Housing_Tenure_renter',
 'Housing_Units_vacant',
 'Housing_Units_occupied',
 'Housing_Units_total',
 'Housing_Units_vacancy_rate',
 'Housing_Units_units_per_acre',
 'Labor_Commute_total_workers_16_and_over',
 'Labor_Commute_car_truck_van_alone',
 'Labor_Commute_car_truck_van_carpool',
 'Labor_Commute_public_transportation',
 'Labor_Commute_walked',
 'Labor_Commute_taxi_moto_bike_other',
 'Labor_Commute_worked_from_home',
 'Labor_Commute_total_commuters',
 'Labor_Commute_share_public_tranportation',
 'Labor_Commute_share_walked',
 'Labor_Commute_share_car_truck_van',
 'Labor_Commute_share_worked_from_home',
 'Labor_LaborForce_in_labor_force_f',
 'Labor_LaborForce_in_labor_force_m',
 'Labor_LaborForce_not_in_labor_force_f',
 'Labor_LaborForce_not_in_labor_force_m',
 'Labor_LaborForce_female_participation_rate',
 'Labor_LaborForce_male_participation_rate',
 'Population_Race_white',
 'Population_Race_black_african_american',
 'Population_Race_other',
 'Population_Race_hispanic_latino',
 'Population_Race_american_indian_alaska_native',
 'Population_Race_asian_pacific_islander',
 'Population_Race_two_plus',
 'Population_Race_share_non_white',
 'Population_Race_share_black_african_american',
 'Population_Race_share_asian_pacific_islander',
 'Population_Race_share_hispanic_latino',
 'Population_Sex_male',
 'Population_Sex_female',
 'Population_Sex_total_pop',
 'Population_Sex_female_share',
 'Population_Density_pop_per_sq_mi',
 'Population_Nativity_native_born',
 'Population_Nativity_foreign_born',
 'Population_Nativity_share_foreign_born',
 'Population_Age_0_to_9',
 'Population_Age_10_to_19',
 'Population_Age_20_to_34',
 'Population_Age_35_to_54',
 'Population_Age_55_to_64',
 'Population_Age_65_plus',
 'Population_Age_share_0_to_9',
 'Population_Age_share_20_to_34',
 'Population_Age_share_55_plus',
 'Population_ChildrenByAge_under5',
 'Population_ChildrenByAge_5_to_17',
 'Population_ChildrenByAge_total_children',
 'Population_ChildrenByAge_share_children',
 'Income_Poverty_tot_pov_stat_det',
 'Income_Poverty_tot_below_pov',
 'Income_Poverty_tot_above_pov',
 'Income_Poverty_pov_rate',
 'Income_ChildrenByPoverty_chi_pov_stat_det',
 'Income_ChildrenByPoverty_chi_below_pov',
 'Income_ChildrenByPoverty_chi_above_pov',
 'Income_ChildrenByPoverty_chi_pov_rate',
 'Education_Attainment_LT_highschool',
 'Education_Attainment_highschool_equivalent',
 'Education_Attainment_some_college',
 'Education_Attainment_bachelors_more',
 'Education_Attainment_share_LT_highschool',
 'Education_Attainment_share_bachelors_more', 
 'sum_violation_count',
 'mean_violation_count',
 'max_violation_count'], class_names=['A', 'B', 'C', 'D', 'Commercial', 'Industrial'], filled=True, proportion=True, rounded=True, fontsize=10)

colors = ["#FDFFA5", "#FDA50A", "#DD513A", "#942668", "#420A68", "#000004"]
from matplotlib.colors import ListedColormap, to_rgb
class_names=['A', 'B', 'C', 'D', 'Commercial', 'Industrial']

for artist, impurity, value in zip(artists, classtree.tree_.impurity, classtree.tree_.value):
    # let the max value decide the color; whiten the color depending on impurity (gini)
    print(class_names[np.argmax(value)])
    r, g, b = to_rgb(colors[np.argmax(value)])
    print(r, g, b)
    f = impurity * (6/5) # for N colors: f = impurity * N/(N-1) if N>1 else 0
    if artist.get_bbox_patch():
        artist.get_bbox_patch().set_facecolor((f + (1-f)*r, f + (1-f)*g, f + (1-f)*b))
        artist.get_bbox_patch().set_edgecolor('black')

        
plt.tight_layout()
plt.show()
# Out:
# C
# 0.8666666666666667 0.3176470588235294 0.22745098039215686
# C
# 0.8666666666666667 0.3176470588235294 0.22745098039215686
# C
# 0.8666666666666667 0.3176470588235294 0.22745098039215686
# Commercial
# 0.25882352941176473 0.0392156862745098 0.40784313725490196
# C
# 0.8666666666666667 0.3176470588235294 0.22745098039215686
# B
# 0.9921568627450981 0.6470588235294118 0.0392156862745098
# C
# 0.8666666666666667 0.3176470588235294 0.22745098039215686
# B
# 0.9921568627450981 0.6470588235294118 0.0392156862745098
# Commercial
# 0.25882352941176473 0.0392156862745098 0.40784313725490196
# Commercial
# 0.25882352941176473 0.0392156862745098 0.40784313725490196
# Commercial
# 0.25882352941176473 0.0392156862745098 0.40784313725490196
# B
# 0.9921568627450981 0.6470588235294118 0.0392156862745098
# C
# 0.8666666666666667 0.3176470588235294 0.22745098039215686
# C
# 0.8666666666666667 0.3176470588235294 0.22745098039215686
# Commercial
# ...
